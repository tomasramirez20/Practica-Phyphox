# %% [markdown]
# <a href="https://colab.research.google.com/github/tomasramirez20/Practica-Phyphox/blob/main/pendulo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# 1. Leer el archivo CSV (asegúrate de que el nombre coincida con tu archivo en "Files")
df = pd.read_csv('Autocorrelation.csv', sep='\t')
t = df['Time shift (s)']
x = df['Autocorrelation of sum']
plt.plot(t, x, color='blue', linewidth=1)
plt.title('Autocorrelacion')
plt.xlabel('Tiempo (s)')
# Out:
# Text(0.5, 0, 'Tiempo (s)')
